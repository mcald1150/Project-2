# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
shooting_incident = "Major Holiday Shootings.csv"

# %%
shooting_incident_df = pd.read_csv(shooting_incident)

# %%
shooting_incident_df.head
# Out:
# <bound method NDFrame.head of         Date        Holiday  Incident Count  Unnamed: 3  Unnamed: 4  \
# 0     1/1/06  New Years Day               8         NaN         NaN
# 1     1/1/07  New Years Day              18         NaN         NaN
# 2     1/1/08  New Years Day              19         NaN         NaN
# 3     1/1/09  New Years Day               7         NaN         NaN
# 4     1/1/10  New Years Day               8         NaN         NaN
# ..       ...            ...             ...         ...         ...
# 73  12/25/14      Christmas               6         NaN         NaN
# 74  12/25/15      Christmas               6         NaN         NaN
# 75  12/25/16      Christmas               3         NaN         NaN
# 76  12/25/17      Christmas               7         NaN         NaN
# 77  12/25/18      Christmas               1         NaN         NaN
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# ...

# %%
new_shooting_incident_df = shooting_incident_df[['Date', 'Holiday', 'Incident Count']].copy()
new_shooting_incident_df.head(60)
# Out:
#        Date           Holiday  Incident Count
# 0    1/1/06     New Years Day               8
# 1    1/1/07     New Years Day              18
# 2    1/1/08     New Years Day              19
# 3    1/1/09     New Years Day               7
# 4    1/1/10     New Years Day               8
# 5    1/1/11     New Years Day              12
# 6    1/1/12     New Years Day              11
# 7    1/1/13     New Years Day              11
# 8    1/1/14     New Years Day              12
# 9    1/1/15     New Years Day               3
# 10   1/1/16     New Years Day               7
# 11   1/1/17     New Years Day               7
# 12   1/1/18     New Years Day               5
# 13   4/4/06  Independence Day               3
# 14   4/4/07  Independence Day               5
# 15   4/4/08  Independence Day               0
# 16   4/4/09  Independence Day               7
# 17   4/4/10  Independence Day               8
# 18   4/4/11  Independence Day               1
# ...
